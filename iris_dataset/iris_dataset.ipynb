# %% [markdown]
# # **Iris Dataset Study**
#
# ## **1. Context**
#
# The Iris dataset was used in R.A. Fisher's classic 1936 paper, The Use of Multiple Measurements in Taxonomic Problems, and can also be found on the UCI Machine Learning Repository.
#
# It includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
# The columns in this dataset are:
#
# * Id
# * SepalLengthCm
# * SepalWidthCm
# * PetalLengthCm
# * PetalWidthCm
# * Species
#
# ## **1.1 Problem**
#
# Predict the species of the iris flower.
#
#
# ## **1.2 Why does this problem need to be solved?**
#
# Through iris flower dataset we expect detect which one species it is to help botanic science work.
#
# ## **1.3 How solve this problem?**
#
# With data model we believe achieve the solution for problem.

# %% [markdown]
# ## 2. **Prepare Dataset**
#
# ## 2.1 **Load dataset**

# %%
import pandas as pd
import matplotlib
with open('data/Iris.csv', 'r') as fo:
    df = pd.read_csv(filepath_or_buffer=fo, sep=',')

df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].hist(figsize=(10,8))
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].plot.kde(figsize=(10,8))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].boxplot(figsize=(10,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### How we can see, the feature SepalWidth has one outlier in lower bound and three outliers in upper bound. Another characteristc the SepalWidth it is the centralized median in boxplot, that indicate a possible normal distribution.

# %%
grouped_df = df.groupby(['Species'])
grouped_df['SepalLengthCm'].plot.kde(figsize=(10,8))
# Out:
# Species
# Iris-setosa        AxesSubplot(0.125,0.125;0.775x0.755)
# Iris-versicolor    AxesSubplot(0.125,0.125;0.775x0.755)
# Iris-virginica     AxesSubplot(0.125,0.125;0.775x0.755)
# Name: SepalLengthCm, dtype: object

# %%
grouped_df['SepalWidthCm'].plot.kde(figsize=(10,8))
# Out:
# Species
# Iris-setosa        AxesSubplot(0.125,0.125;0.775x0.755)
# Iris-versicolor    AxesSubplot(0.125,0.125;0.775x0.755)
# Iris-virginica     AxesSubplot(0.125,0.125;0.775x0.755)
# Name: SepalWidthCm, dtype: object

# %%
grouped_df['PetalLengthCm'].plot.kde(figsize=(10,8))
# Out:
# Species
# Iris-setosa        AxesSubplot(0.125,0.125;0.775x0.755)
# Iris-versicolor    AxesSubplot(0.125,0.125;0.775x0.755)
# Iris-virginica     AxesSubplot(0.125,0.125;0.775x0.755)
# Name: PetalLengthCm, dtype: object

# %%
grouped_df['PetalWidthCm'].plot.kde(figsize=(10,8))
# Out:
# Species
# Iris-setosa        AxesSubplot(0.125,0.125;0.775x0.755)
# Iris-versicolor    AxesSubplot(0.125,0.125;0.775x0.755)
# Iris-virginica     AxesSubplot(0.125,0.125;0.775x0.755)
# Name: PetalWidthCm, dtype: object

# %%
# Correlation
corr =  df.corr(method='pearson')
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_aa4ab_row0_col0,#T_aa4ab_row1_col1,#T_aa4ab_row2_col2,#T_aa4ab_row3_col3,#T_aa4ab_row4_col4{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_aa4ab_row0_col1{
#             background-color:  #f59c7d;
#             color:  #000000;
#         }#T_aa4ab_row0_col2{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_aa4ab_row0_col3,#T_aa4ab_row3_col0{
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }#T_aa4ab_row0_col4,#T_aa4ab_row4_col0{
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }#T_aa4ab_row1_col0{
#             background-color:  #ee8468;
#             color:  #000000;
#         }#T_aa4ab_row1_col2{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_aa4ab_row1_col3{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_aa4ab_row1_col4{
# ...

# %%
# Dimensionality

# Sparsity

# Resolution: Pattern depend on the scale; Aggregated data

# Distribution: Centrality and dispersion
